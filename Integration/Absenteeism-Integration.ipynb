# %% [markdown]
# **Import absenteeism_module**

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
from absenteeism_module import *

# %% [markdown]
# **Read the CSV File**

# %%
pd.read_csv('Absenteeism_new_data.csv')
# Out:
#     ID  Reason for Absence        Date  Transportation Expense  \
# 0   22                  27  01/06/2018                     179
# 1   10                   7  04/06/2018                     361
# 2   14                  23  06/06/2018                     155
# 3   17                  25  08/06/2018                     179
# 4   14                  10  08/06/2018                     155
# 5   28                  11  11/06/2018                     225
# 6   16                   7  13/06/2018                     118
# 7   22                  27  13/06/2018                     179
# 8   34                  26  15/06/2018                     118
# 9   34                  10  20/06/2018                     118
# 10  23                  22  21/06/2018                     378
# 11  36                  19  21/06/2018                     118
# 12  12                  19  22/06/2018                     233
# 13  22                  27  22/06/2018                     179
# ...

# %% [markdown]
# **Initialize the Model to Predict Absenteeism**

# %%
model = absenteeism_model('absenteeism_model','absenteeism_scaler')

# %% [markdown]
# **Load the Data for Cleaning and Processing**

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')

# %% [markdown]
# **Predict Outputs**

# %%
model.predicted_outputs()
# Out:
#     Reason 1  Reason 2  Reason 3  Reason 4  Month Value  \
# 0          0       0.0         0         1            6
# 1          1       0.0         0         0            6
# 2          0       0.0         0         1            6
# 3          0       0.0         0         1            6
# 4          1       0.0         0         0            6
# 5          1       0.0         0         0            6
# 6          1       0.0         0         0            6
# 7          0       0.0         0         1            6
# 8          0       0.0         0         1            6
# 9          1       0.0         0         0            6
# 10         0       0.0         0         1            6
# 11         0       0.0         1         0            6
# 12         0       0.0         1         0            6
# 13         0       0.0         0         1            6
# 14         0       0.0         0         0            6
# 15         0       0.0         0         0            6
# ...

# %% [markdown]
# **Save the Predicted Outputs to a CSV File**

# %%
model.predicted_outputs().to_csv('Absenteeism_predictions.csv', index = False)
